# %%
import seaborn as sns
from datetime import date
start = date(2020, 2, 1)
end = date(2020, 2, 29)

# %% [markdown]
# # Cash Index

# %%
from mpr import cash_index
cash = await cash_index.get(start, end)
cash
# Out:
#             CME Index  Index Change  Daily Avg Price  Price Change  \
# date
# 2020-02-03      61.10         -0.31            61.09         -0.02
# 2020-02-05      60.61         -0.49            60.00         -1.09
# 2020-02-06      59.48         -1.13            59.13         -0.87
# 2020-02-07      58.46         -1.02            58.03         -1.10
# 2020-02-10      57.93         -0.53            57.79         -0.24
# 2020-02-11      57.32         -0.61            56.85         -0.94
# 2020-02-12      56.70         -0.62            56.55         -0.30
# 2020-02-13      56.38         -0.32            56.21         -0.34
# 2020-02-14      55.97         -0.41            55.78         -0.43
# 2020-02-17      55.66         -0.31            55.47         -0.31
# 2020-02-18      55.54         -0.12            55.61          0.14
# 2020-02-19      55.78          0.24            55.94          0.33
# 2020-02-20      55.87          0.09            55.80         -0.14
# ...

# %%
cash['CME Index'].plot()

# %% [markdown]
# # Cutout Index

# %%
from mpr import cutout_index
cutout = await cutout_index.get(start, end)
cutout
# Out:
#             Cutout Index  Index Change  Carcass Price  Price Change  \
# date
# 2020-02-03         71.72         -1.35          69.84          0.27
# 2020-02-04         69.95         -1.77          68.13         -1.71
# 2020-02-05         68.82         -1.13          65.30         -2.83
# 2020-02-06         67.69         -1.13          65.35          0.05
# 2020-02-07         66.73         -0.96          64.81         -0.54
# 2020-02-10         65.81         -0.92          65.02          0.21
# 2020-02-11         64.80         -1.01          63.65         -1.37
# 2020-02-12         64.55         -0.25          63.96          0.31
# 2020-02-13         64.11         -0.44          63.10         -0.86
# 2020-02-14         63.69         -0.42          62.75         -0.35
# 2020-02-17         63.28         -0.41          62.86          0.11
# 2020-02-18         63.59          0.31          65.01          2.15
# 2020-02-19         63.60          0.01          64.01         -1.00
# ...

# %%
cutout['Cutout Index'].plot()

# %% [markdown]
# # Purchases

# %%
from mpr import purchase_index
purchases = await purchase_index.get(start, end)
purchases
# Out:
#             Purchase Index  Index Change  Daily Avg Price  Price Change  \
# date
# 2020-02-03           59.71         -0.30            58.91         -0.11
# 2020-02-04           59.23         -0.48            58.06         -0.85
# 2020-02-05           58.54         -0.69            56.71         -1.35
# 2020-02-06           57.82         -0.72            56.01         -0.70
# 2020-02-07           56.84         -0.98            55.34         -0.67
# 2020-02-10           56.11         -0.73            54.76         -0.58
# 2020-02-11           55.41         -0.70            54.29         -0.47
# 2020-02-12           54.89         -0.52            53.91         -0.38
# 2020-02-13           54.40         -0.49            53.34         -0.57
# 2020-02-14           53.87         -0.53            53.28         -0.06
# 2020-02-17           53.62         -0.25            53.35          0.07
# 2020-02-18           53.42         -0.20            53.22         -0.13
# ...

# %%
purchases['Purchase Index'].plot()

# %% [markdown]
# # Bacon Index

# %%
from mpr import bacon_index
bacon = await bacon_index.get(date(2020, 1, 1), end)
bacon
# Out:
#             Bacon Index  Index Change  Total Weight  Negotiated Price  \
# date
# 2020-01-03       111.13        -11.56      17895632             99.18
# 2020-01-10       113.85          2.72      20233597            106.61
# 2020-01-17       125.40         11.55      18967339            120.56
# 2020-01-24       141.99         16.59      18454505            132.25
# 2020-01-31       143.34          1.35      17574430            125.23
# 2020-02-07       124.58        -18.76      18457974            105.49
# 2020-02-14       104.40        -20.18      16902103             87.94
# 2020-02-21        97.55         -6.85      18475229             86.38
#
#             Negotiated Weight  Formula Price  Formula Weight
# date
# 2020-01-03            4760964         115.46        13134668
# 2020-01-10            4643246         116.00        15590351
# 2020-01-17            2045559         125.99        16921780
# 2020-01-24            2358924         143.41        16095581
# ...
