# %%
from cash_index import get_cash_index

# first, we'll read the daily slaughter report (LM_HG201) and compute the daily CME Lean Hog Index
cash_index = get_cash_index()

# what are the last 5 days of the cash index?
cash_index.tail()
# Out:
# date
# 2018-08-07    63.172839
# 2018-08-08    61.884775
# 2018-08-09    60.043782
# 2018-08-10    58.282722
# 2018-08-13    56.812162
# Name: cash_index, dtype: float64

# %%
# %matplotlib inline

# let's plot it on a chart
cash_index['2018'].plot()
