# %%
# library for running multiple asyncio event loops. currently required to use async functions in jupyter
import nest_asyncio 
nest_asyncio.apply()

# This function replicates the daily hog data published by the CME as a pandas DataFrame
# ftp://ftp.cmegroup.com/cash_settled_commodity_index_prices/daily_data/lean_hogs/LH180827.txt
from cash_prices import get_cash_prices

cash_prices = get_cash_prices(days=60)

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

cash_prices.tail()
# Out:
#             Negotiated Head Count  Negotiated Carcass Weight  \
# date
# 2018-08-30                  11640                     199.83
# 2018-08-31                  12612                     199.14
# 2018-09-04                   7556                     192.70
# 2018-09-05                   8497                     205.72
# 2018-09-06                  10031                     198.43
#
#             Negotiated Net Price  Market Formula Head Count  \
# date
# 2018-08-30                 39.57                     144892
# 2018-08-31                 39.03                     172058
# 2018-09-04                 38.83                     122021
# 2018-09-05                 37.94                     131786
# 2018-09-06                 38.45                     129551
#
#             Market Formula Carcass Weight  Market Formula Net Price  \
# date
# 2018-08-30                         208.64                     46.07
# 2018-08-31                         208.51                     45.74
# 2018-09-04                         207.56                     46.63
# 2018-09-05                         208.42                     46.14
# 2018-09-06                         209.13                     46.95
#
#             Daily Weighted Price  Price Change  CME Index  Index Change
# date
# 2018-08-30                 45.61         -0.06      45.63         -0.22
# 2018-08-31                 45.30         -0.30      45.44         -0.19
# 2018-09-04                 46.21          0.90      45.67          0.23
# 2018-09-05                 45.65         -0.56      45.92          0.24
# 2018-09-06                 46.37          0.72      46.01          0.09

# %%
# What was the CME Index for the last 10 days?
cash_prices[['CME Index', 'Index Change']].tail(10)
# Out:
#             CME Index  Index Change
# date
# 2018-08-23      48.93         -0.57
# 2018-08-24      47.79         -1.14
# 2018-08-27      47.09         -0.69
# 2018-08-28      46.45         -0.64
# 2018-08-29      45.85         -0.60
# 2018-08-30      45.63         -0.22
# 2018-08-31      45.44         -0.19
# 2018-09-04      45.67          0.23
# 2018-09-05      45.92          0.24
# 2018-09-06      46.01          0.09

# %%
# %matplotlib inline

# Plot the CME Index on a chart
cash_prices['CME Index'].plot()
