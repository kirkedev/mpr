# %%
from datetime import date
from cash_index import get_cash_index

# download the daily slaughter report for 2018 and compute the CME Lean Hog Index
# the download takes some time, so you only need to run this cell once

cash_index = get_cash_index(start_date=date(2018, 1, 1))

# %%
# what are the last 5 days of the cash index?
cash_index.tail()
# Out:
# date
# 2018-08-13    56.812162
# 2018-08-14    55.233887
# 2018-08-15    54.212564
# 2018-08-16    52.935702
# 2018-08-17    51.506186
# Name: cash_index, dtype: float64

# %%
# %matplotlib inline

# plot it on a chart
cash_index.plot()
